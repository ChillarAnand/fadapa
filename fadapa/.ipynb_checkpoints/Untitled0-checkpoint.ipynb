# %%
from FastQCP import Parser
d = Parser('fastqc_data.txt')
#print(d.file_name)
#print(d.modules())
#print(d.raw_data('Basic Statistics'))
print(d.data('Basic Statistics'))
# Out:
# None ['##FastQC\t0.10.1']
# True ['>>Basic Statistics\tpass']
# None ['#Measure\tValue\t', 'Filename\tsample1.fastq\t', 'File type\tConventional base calls\t', 'Encoding\tSanger / Illumina 1.9\t', 'Total Sequences\t1571332\t', 'Filtered Sequences\t0\t', 'Sequence length\t29\t', '%GC\t53', '>>END_MODULE']
# True ['>>Per base sequence quality\tpass']
# ...

# %%
# Out:
# fastqc_data.txt

# %%
# Out:
# Basic Statistics
# Per base sequence quality
# Per sequence quality scores
# Per base sequence content
# Per base GC content
# Per sequence GC content
# Per base N content
# Sequence Length Distribution
# Sequence Duplication Levels
# Overrepresented sequences
# Kmer Content
# None

# %%
# Out:
# ['>>Basic Statistics\tpass',
#  '#Measure\tValue\t',
#  'Filename\tsample1.fastq\t',
#  'File type\tConventional base calls\t',
#  'Encoding\tSanger / Illumina 1.9\t',
#  'Total Sequences\t1571332\t',
#  'Filtered Sequences\t0\t',
#  'Sequence length\t29\t',
#  '%GC\t53',
#  '>>END_MODULE']

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-4f1564abaf2b> in <module>()
# ----> 1 d.data('Basic Statistics')
#
# NameError: name 'd' is not defined
